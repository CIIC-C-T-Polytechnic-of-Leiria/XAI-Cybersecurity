# %% [markdown]
# # DNN

# %% [markdown]
# ## Import and Reading Data

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LeakyReLU
# Out:
# 2024-04-22 14:42:29.013624: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-22 14:42:29.014007: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-22 14:42:29.016197: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-22 14:42:29.043913: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 14:42:29.577305: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load Train and Test Datasets

# %%
# Load training data
df_train = pd.read_csv('../0_Datasets/CICIDS-2017/train.csv')

# %%
# Load testing data
df_test = pd.read_csv('../0_Datasets/CICIDS-2017/test.csv')

# %%
X_train = df_train.drop(['label'], axis=1)  # Features
y_train = df_train['label']  # Target variable

# %%
X_test = df_test.drop(['label'], axis=1)  # Features
y_test = df_test['label']  # Target variable

# %%
X_train, X_train_test, y_train, y_train_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# -----
# ## Create Model and Train Model

# %%
X_train.shape,y_train.shape
# Out:
# ((205989, 7), (205989,))

# %%
X_train_test.shape, y_train_test.shape
# Out:
# ((51498, 7), (51498,))

# %%
X_test.shape,y_test.shape
# Out:
# ((28609, 7), (28609,))

# %%
# %%time

# Define the model
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
# Out:
# CPU times: user 83.8 ms, sys: 9.42 ms, total: 93.2 ms
# Wall time: 90.5 ms
# /home/ivoafonsobispo/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-04-22 14:42:30.212530: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-22 14:42:30.212844: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Compile the model with learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Define early stopping
monitor = tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor=0.5,mode="min",patience=10,verbose=1,min_lr=1e-7)
checkpoint = ModelCheckpoint('Saved_Models/CICIDS-2017_DNN.keras', monitor='val_loss', save_best_only=True)

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_train_test, y_train_test), epochs=100, batch_size=512, callbacks=[monitor, checkpoint])
# Out:
# Epoch 1/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - accuracy: 0.7137 - loss: 0.5811 - val_accuracy: 0.7531 - val_loss: 0.6557 - learning_rate: 0.0010
# Epoch 2/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8949 - loss: 0.3016 - val_accuracy: 0.8376 - val_loss: 0.3482 - learning_rate: 0.0010
# Epoch 3/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9072 - loss: 0.2727 - val_accuracy: 0.8308 - val_loss: 0.3643 - learning_rate: 0.0010
# Epoch 4/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9125 - loss: 0.2620 - val_accuracy: 0.7586 - val_loss: 0.6311 - learning_rate: 0.0010
# Epoch 5/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9161 - loss: 0.2526 - val_accuracy: 0.7334 - val_loss: 0.6880 - learning_rate: 0.0010
# Epoch 6/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9183 - loss: 0.2489 - val_accuracy: 0.7729 - val_loss: 0.4993 - learning_rate: 0.0010
# Epoch 7/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9203 - loss: 0.2441 - val_accuracy: 0.7576 - val_loss: 0.5283 - learning_rate: 0.0010
# Epoch 8/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9219 - loss: 0.2385 - val_accuracy: 0.9003 - val_loss: 0.2643 - learning_rate: 0.0010
# Epoch 9/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9212 - loss: 0.2396 - val_accuracy: 0.8757 - val_loss: 0.2929 - learning_rate: 0.0010
# Epoch 10/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9220 - loss: 0.2367 - val_accuracy: 0.7489 - val_loss: 0.6157 - learning_rate: 0.0010
# Epoch 11/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9216 - loss: 0.2376 - val_accuracy: 0.8515 - val_loss: 0.3153 - learning_rate: 0.0010
# Epoch 12/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9230 - loss: 0.2358 - val_accuracy: 0.7689 - val_loss: 0.5447 - learning_rate: 0.0010
# Epoch 13/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9235 - loss: 0.2344 - val_accuracy: 0.7820 - val_loss: 0.5154 - learning_rate: 0.0010
# Epoch 14/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9239 - loss: 0.2330 - val_accuracy: 0.7967 - val_loss: 0.4889 - learning_rate: 0.0010
# Epoch 15/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9227 - loss: 0.2346 - val_accuracy: 0.9019 - val_loss: 0.3330 - learning_rate: 0.0010
# Epoch 16/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9234 - loss: 0.2348 - val_accuracy: 0.7623 - val_loss: 0.6283 - learning_rate: 0.0010
# Epoch 17/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9247 - loss: 0.2302 - val_accuracy: 0.7471 - val_loss: 0.6122 - learning_rate: 0.0010
# Epoch 18/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9236 - loss: 0.2320 - val_accuracy: 0.8217 - val_loss: 0.3469 - learning_rate: 0.0010
# Epoch 19/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9237 - loss: 0.2327 - val_accuracy: 0.9065 - val_loss: 0.2471 - learning_rate: 0.0010
# Epoch 20/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9254 - loss: 0.2284 - val_accuracy: 0.9021 - val_loss: 0.2579 - learning_rate: 0.0010
# Epoch 21/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9244 - loss: 0.2310 - val_accuracy: 0.7878 - val_loss: 0.5109 - learning_rate: 0.0010
# Epoch 22/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9253 - loss: 0.2283 - val_accuracy: 0.8649 - val_loss: 0.2941 - learning_rate: 0.0010
# Epoch 23/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9253 - loss: 0.2286 - val_accuracy: 0.8423 - val_loss: 0.3919 - learning_rate: 0.0010
# Epoch 24/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9253 - loss: 0.2277 - val_accuracy: 0.8644 - val_loss: 0.2863 - learning_rate: 0.0010
# Epoch 25/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9249 - loss: 0.2270 - val_accuracy: 0.8761 - val_loss: 0.3243 - learning_rate: 0.0010
# Epoch 26/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9255 - loss: 0.2271 - val_accuracy: 0.8173 - val_loss: 0.4649 - learning_rate: 0.0010
# Epoch 27/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9254 - loss: 0.2271 - val_accuracy: 0.8217 - val_loss: 0.4216 - learning_rate: 0.0010
# Epoch 28/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9273 - loss: 0.2245 - val_accuracy: 0.8806 - val_loss: 0.3349 - learning_rate: 0.0010
# Epoch 29/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9256 - loss: 0.2265 - val_accuracy: 0.8633 - val_loss: 0.3099 - learning_rate: 0.0010
# Epoch 30/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9244 - loss: 0.2282 - val_accuracy: 0.8409 - val_loss: 0.3901 - learning_rate: 0.0010
# Epoch 31/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9247 - loss: 0.2270 - val_accuracy: 0.8443 - val_loss: 0.3672 - learning_rate: 0.0010
# Epoch 32/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9250 - loss: 0.2285 - val_accuracy: 0.8315 - val_loss: 0.4029 - learning_rate: 0.0010
# Epoch 33/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9255 - loss: 0.2278 - val_accuracy: 0.8766 - val_loss: 0.2848 - learning_rate: 0.0010
# Epoch 34/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9261 - loss: 0.2254 - val_accuracy: 0.7410 - val_loss: 0.6731 - learning_rate: 0.0010
# Epoch 35/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9228 - loss: 0.2308 - val_accuracy: 0.9123 - val_loss: 0.2351 - learning_rate: 0.0010
# Epoch 36/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9262 - loss: 0.2250 - val_accuracy: 0.7479 - val_loss: 0.6191 - learning_rate: 0.0010
# Epoch 37/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9260 - loss: 0.2255 - val_accuracy: 0.9313 - val_loss: 0.4612 - learning_rate: 0.0010
# Epoch 38/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9252 - loss: 0.2265 - val_accuracy: 0.9051 - val_loss: 0.2505 - learning_rate: 0.0010
# Epoch 39/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9265 - loss: 0.2241 - val_accuracy: 0.8019 - val_loss: 0.4711 - learning_rate: 0.0010
# Epoch 40/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9260 - loss: 0.2249 - val_accuracy: 0.9013 - val_loss: 0.3248 - learning_rate: 0.0010
# Epoch 41/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9255 - loss: 0.2245 - val_accuracy: 0.9159 - val_loss: 0.2446 - learning_rate: 0.0010
# Epoch 42/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9259 - loss: 0.2255 - val_accuracy: 0.9104 - val_loss: 0.3601 - learning_rate: 0.0010
# Epoch 43/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9266 - loss: 0.2225 - val_accuracy: 0.7182 - val_loss: 0.7393 - learning_rate: 0.0010
# Epoch 44/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9264 - loss: 0.2242 - val_accuracy: 0.4441 - val_loss: 1.3251 - learning_rate: 0.0010
# Epoch 45/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9253 - loss: 0.2255 - val_accuracy: 0.8269 - val_loss: 0.4276 - learning_rate: 0.0010
# Epoch 46/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9265 - loss: 0.2241 - val_accuracy: 0.9088 - val_loss: 0.2497 - learning_rate: 0.0010
# Epoch 47/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9248 - loss: 0.2273 - val_accuracy: 0.9046 - val_loss: 0.2718 - learning_rate: 0.0010
# Epoch 48/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9262 - loss: 0.2244 - val_accuracy: 0.8787 - val_loss: 0.3085 - learning_rate: 0.0010
# Epoch 49/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9259 - loss: 0.2243 - val_accuracy: 0.8184 - val_loss: 0.4715 - learning_rate: 0.0010
# Epoch 50/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9261 - loss: 0.2229 - val_accuracy: 0.8328 - val_loss: 0.4277 - learning_rate: 0.0010
# Epoch 51/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9267 - loss: 0.2228 - val_accuracy: 0.9150 - val_loss: 0.2438 - learning_rate: 0.0010
# Epoch 52/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9257 - loss: 0.2251 - val_accuracy: 0.8949 - val_loss: 0.2618 - learning_rate: 0.0010
# Epoch 53/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9269 - loss: 0.2222 - val_accuracy: 0.8061 - val_loss: 0.5165 - learning_rate: 0.0010
# Epoch 54/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9264 - loss: 0.2233 - val_accuracy: 0.8241 - val_loss: 0.4259 - learning_rate: 0.0010
# Epoch 55/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9264 - loss: 0.2226 - val_accuracy: 0.9158 - val_loss: 0.2270 - learning_rate: 0.0010
# Epoch 56/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9269 - loss: 0.2216 - val_accuracy: 0.8308 - val_loss: 0.4170 - learning_rate: 0.0010
# Epoch 57/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9269 - loss: 0.2218 - val_accuracy: 0.8830 - val_loss: 0.3434 - learning_rate: 0.0010
# Epoch 58/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9258 - loss: 0.2252 - val_accuracy: 0.8996 - val_loss: 0.3301 - learning_rate: 0.0010
# Epoch 59/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9270 - loss: 0.2230 - val_accuracy: 0.8340 - val_loss: 0.3364 - learning_rate: 0.0010
# Epoch 60/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9266 - loss: 0.2241 - val_accuracy: 0.9059 - val_loss: 0.3413 - learning_rate: 0.0010
# Epoch 61/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9267 - loss: 0.2228 - val_accuracy: 0.9176 - val_loss: 0.2421 - learning_rate: 0.0010
# Epoch 62/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9264 - loss: 0.2232 - val_accuracy: 0.7927 - val_loss: 0.5752 - learning_rate: 0.0010
# Epoch 63/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9273 - loss: 0.2204 - val_accuracy: 0.8921 - val_loss: 0.3154 - learning_rate: 0.0010
# Epoch 64/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9265 - loss: 0.2241 - val_accuracy: 0.9234 - val_loss: 0.2247 - learning_rate: 0.0010
# Epoch 65/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9269 - loss: 0.2230 - val_accuracy: 0.8857 - val_loss: 0.2782 - learning_rate: 0.0010
# Epoch 66/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9263 - loss: 0.2230 - val_accuracy: 0.7755 - val_loss: 0.6210 - learning_rate: 0.0010
# Epoch 67/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9267 - loss: 0.2227 - val_accuracy: 0.9152 - val_loss: 0.2462 - learning_rate: 0.0010
# Epoch 68/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9269 - loss: 0.2219 - val_accuracy: 0.8681 - val_loss: 0.2983 - learning_rate: 0.0010
# Epoch 69/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9269 - loss: 0.2214 - val_accuracy: 0.8364 - val_loss: 0.3924 - learning_rate: 0.0010
# Epoch 70/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9284 - loss: 0.2184 - val_accuracy: 0.9019 - val_loss: 0.2387 - learning_rate: 0.0010
# Epoch 71/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9269 - loss: 0.2215 - val_accuracy: 0.7996 - val_loss: 0.4570 - learning_rate: 0.0010
# Epoch 72/100
# 393/403 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9275 - loss: 0.2207
# Epoch 72: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9274 - loss: 0.2207 - val_accuracy: 0.9067 - val_loss: 0.3315 - learning_rate: 0.0010
# Epoch 73/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9271 - loss: 0.2211 - val_accuracy: 0.8655 - val_loss: 0.3495 - learning_rate: 5.0000e-04
# Epoch 74/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9274 - loss: 0.2199 - val_accuracy: 0.8861 - val_loss: 0.3192 - learning_rate: 5.0000e-04
# Epoch 75/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9271 - loss: 0.2200 - val_accuracy: 0.8664 - val_loss: 0.3594 - learning_rate: 5.0000e-04
# Epoch 76/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9272 - loss: 0.2210 - val_accuracy: 0.8401 - val_loss: 0.3298 - learning_rate: 5.0000e-04
# Epoch 77/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9263 - loss: 0.2226 - val_accuracy: 0.8866 - val_loss: 0.3363 - learning_rate: 5.0000e-04
# Epoch 78/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9278 - loss: 0.2196 - val_accuracy: 0.8321 - val_loss: 0.4940 - learning_rate: 5.0000e-04
# Epoch 79/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9272 - loss: 0.2206 - val_accuracy: 0.9254 - val_loss: 0.2953 - learning_rate: 5.0000e-04
# Epoch 80/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9270 - loss: 0.2211 - val_accuracy: 0.9251 - val_loss: 0.2255 - learning_rate: 5.0000e-04
# Epoch 81/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9275 - loss: 0.2191 - val_accuracy: 0.9238 - val_loss: 0.2187 - learning_rate: 5.0000e-04
# Epoch 82/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9274 - loss: 0.2206 - val_accuracy: 0.8865 - val_loss: 0.2997 - learning_rate: 5.0000e-04
# Epoch 83/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9277 - loss: 0.2188 - val_accuracy: 0.9221 - val_loss: 0.2334 - learning_rate: 5.0000e-04
# Epoch 84/100
# 397/403 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9285 - loss: 0.2178
# Epoch 84: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9285 - loss: 0.2178 - val_accuracy: 0.8663 - val_loss: 0.3578 - learning_rate: 5.0000e-04
# Epoch 85/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9270 - loss: 0.2219 - val_accuracy: 0.9176 - val_loss: 0.2412 - learning_rate: 2.5000e-04
# Epoch 86/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9280 - loss: 0.2178 - val_accuracy: 0.9189 - val_loss: 0.2426 - learning_rate: 2.5000e-04
# Epoch 87/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9279 - loss: 0.2203 - val_accuracy: 0.8568 - val_loss: 0.3858 - learning_rate: 2.5000e-04
# Epoch 88/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9277 - loss: 0.2196 - val_accuracy: 0.8967 - val_loss: 0.2836 - learning_rate: 2.5000e-04
# Epoch 89/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9284 - loss: 0.2177 - val_accuracy: 0.8424 - val_loss: 0.4034 - learning_rate: 2.5000e-04
# Epoch 90/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9285 - loss: 0.2179 - val_accuracy: 0.8993 - val_loss: 0.2455 - learning_rate: 2.5000e-04
# Epoch 91/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9278 - loss: 0.2181 - val_accuracy: 0.8640 - val_loss: 0.3503 - learning_rate: 2.5000e-04
# Epoch 92/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9282 - loss: 0.2191 - val_accuracy: 0.9228 - val_loss: 0.2245 - learning_rate: 2.5000e-04
# Epoch 93/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9282 - loss: 0.2180 - val_accuracy: 0.9204 - val_loss: 0.2394 - learning_rate: 2.5000e-04
# Epoch 94/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9288 - loss: 0.2167 - val_accuracy: 0.8923 - val_loss: 0.3044 - learning_rate: 2.5000e-04
# Epoch 95/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9278 - loss: 0.2194 - val_accuracy: 0.9210 - val_loss: 0.2307 - learning_rate: 2.5000e-04
# Epoch 96/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9278 - loss: 0.2184 - val_accuracy: 0.8934 - val_loss: 0.3135 - learning_rate: 2.5000e-04
# Epoch 97/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9284 - loss: 0.2180 - val_accuracy: 0.8962 - val_loss: 0.2702 - learning_rate: 2.5000e-04
# Epoch 98/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9273 - loss: 0.2210 - val_accuracy: 0.9216 - val_loss: 0.2403 - learning_rate: 2.5000e-04
# Epoch 99/100
# 390/403 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9286 - loss: 0.2176
# Epoch 99: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9285 - loss: 0.2177 - val_accuracy: 0.9192 - val_loss: 0.2394 - learning_rate: 2.5000e-04
# Epoch 100/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9282 - loss: 0.2167 - val_accuracy: 0.9188 - val_loss: 0.2340 - learning_rate: 1.2500e-04

# %%
# Load the best saved model
best_model = load_model('Saved_Models/CICIDS-2017_DNN.keras')

# %%
pred = model.predict(X_train_test)
# Out:
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 1s 435us/step

# %%
fig, ax = plt.subplots(figsize=(20, 16))

ax.plot(history.history['loss'], label='train')
ax.plot(history.history['val_loss'], label='test')
ax.set_title('Model Loss')
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
ax.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Results

# %% [markdown]
# ### Training

# %%
threshold = 0.5  # Adjust the threshold as needed
pred = (pred > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_train_test, pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
accuracy = accuracy_score(y_train_test, pred)
precision = precision_score(y_train_test, pred)
recall = recall_score(y_train_test, pred)
f1 = f1_score(y_train_test, pred)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   91.88%
# Precision:  88.80%
# Recall:     97.73%
# F1-score:   93.05%

# %% [markdown]
# ### with Test Dataset

# %%
pred_test = model.predict(X_test)
# Out:
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 0s 399us/step

# %%
threshold = 0.5  # Adjust the threshold as needed
pred_test = (pred_test > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, pred_test)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Compute accuracy
accuracy = accuracy_score(y_test, pred_test)
precision = precision_score(y_test, pred_test)
recall = recall_score(y_test, pred_test)
f1 = f1_score(y_test, pred_test)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   91.37%
# Precision:  88.35%
# Recall:     97.27%
# F1-score:   92.60%
