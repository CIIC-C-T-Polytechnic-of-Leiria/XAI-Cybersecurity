# %% [markdown]
# ## Import and Reading Data

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LeakyReLU
# Out:
# 2024-04-22 14:47:17.225581: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-22 14:47:17.226113: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-22 14:47:17.228379: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-22 14:47:17.258008: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 14:47:17.797879: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load Train and Test Datasets

# %%
# Load training data
df_train = pd.read_csv('../0_Datasets/IoMT_AI_IDS/train.csv')

# %%
# Load testing data
df_test = pd.read_csv('../0_Datasets/IoMT_AI_IDS/test.csv')

# %%
X_train = df_train.drop(['is_attack'], axis=1)  # Features
y_train = df_train['is_attack']  # Target variable

# %%
X_test = df_test.drop(['is_attack'], axis=1)  # Features
y_test = df_test['is_attack']  # Target variable

# %%
X_train, X_train_test, y_train, y_train_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# -----
# ## Create Model and Train Model

# %%
X_train.shape,y_train.shape
# Out:
# ((58452, 33), (58452,))

# %%
X_train_test.shape, y_train_test.shape
# Out:
# ((14614, 33), (14614,))

# %%
X_test.shape,y_test.shape
# Out:
# ((8118, 33), (8118,))

# %%
# %%time

# Define the model
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
# Out:
# CPU times: user 96.9 ms, sys: 508 µs, total: 97.4 ms
# Wall time: 94.7 ms
# /home/ivoafonsobispo/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-04-22 14:47:18.498085: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-22 14:47:18.498362: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Compile the model with learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Define early stopping
monitor = tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor=0.5,mode="min",patience=10,verbose=1,min_lr=1e-7)
checkpoint = ModelCheckpoint('Saved_Models/IoMT_AI_IDS_DNN.keras', monitor='val_loss', save_best_only=True)

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_train_test, y_train_test), epochs=100, batch_size=512, callbacks=[monitor, checkpoint])
# Out:
# Epoch 1/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9055 - loss: 0.2548 - val_accuracy: 0.9884 - val_loss: 0.0717 - learning_rate: 0.0010
# Epoch 2/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9884 - loss: 0.0749 - val_accuracy: 0.9892 - val_loss: 0.0579 - learning_rate: 0.0010
# Epoch 3/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9891 - loss: 0.0669 - val_accuracy: 0.9893 - val_loss: 0.0582 - learning_rate: 0.0010
# Epoch 4/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9896 - loss: 0.0622 - val_accuracy: 0.9893 - val_loss: 0.0572 - learning_rate: 0.0010
# Epoch 5/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9894 - loss: 0.0607 - val_accuracy: 0.9893 - val_loss: 0.0557 - learning_rate: 0.0010
# Epoch 6/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9889 - loss: 0.0612 - val_accuracy: 0.9893 - val_loss: 0.0551 - learning_rate: 0.0010
# Epoch 7/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9896 - loss: 0.0578 - val_accuracy: 0.9893 - val_loss: 0.0537 - learning_rate: 0.0010
# Epoch 8/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9904 - loss: 0.0526 - val_accuracy: 0.9893 - val_loss: 0.0523 - learning_rate: 0.0010
# Epoch 9/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9892 - loss: 0.0574 - val_accuracy: 0.9894 - val_loss: 0.0524 - learning_rate: 0.0010
# Epoch 10/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9897 - loss: 0.0562 - val_accuracy: 0.9894 - val_loss: 0.0527 - learning_rate: 0.0010
# Epoch 11/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9903 - loss: 0.0517 - val_accuracy: 0.9893 - val_loss: 0.0521 - learning_rate: 0.0010
# Epoch 12/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0534 - val_accuracy: 0.9893 - val_loss: 0.0516 - learning_rate: 0.0010
# Epoch 13/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9896 - loss: 0.0555 - val_accuracy: 0.9893 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 14/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9903 - loss: 0.0516 - val_accuracy: 0.9895 - val_loss: 0.0508 - learning_rate: 0.0010
# Epoch 15/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0528 - val_accuracy: 0.9894 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 16/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0518 - val_accuracy: 0.9895 - val_loss: 0.0508 - learning_rate: 0.0010
# Epoch 17/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0553 - val_accuracy: 0.9895 - val_loss: 0.0511 - learning_rate: 0.0010
# Epoch 18/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0539 - val_accuracy: 0.9895 - val_loss: 0.0511 - learning_rate: 0.0010
# Epoch 19/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9902 - loss: 0.0526 - val_accuracy: 0.9895 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 20/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9896 - loss: 0.0522 - val_accuracy: 0.9895 - val_loss: 0.0511 - learning_rate: 0.0010
# Epoch 21/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9893 - loss: 0.0550 - val_accuracy: 0.9895 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 22/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0545 - val_accuracy: 0.9895 - val_loss: 0.0513 - learning_rate: 0.0010
# Epoch 23/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9900 - loss: 0.0540 - val_accuracy: 0.9895 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 24/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9903 - loss: 0.0516 - val_accuracy: 0.9895 - val_loss: 0.0514 - learning_rate: 0.0010
# Epoch 25/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9899 - loss: 0.0531 - val_accuracy: 0.9895 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 26/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0519 - val_accuracy: 0.9895 - val_loss: 0.0517 - learning_rate: 0.0010
# Epoch 27/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9898 - loss: 0.0525 - val_accuracy: 0.9895 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 28/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9898 - loss: 0.0530 - val_accuracy: 0.9895 - val_loss: 0.0517 - learning_rate: 0.0010
# Epoch 29/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9896 - loss: 0.0533 - val_accuracy: 0.9895 - val_loss: 0.0511 - learning_rate: 0.0010
# Epoch 30/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9894 - loss: 0.0529 - val_accuracy: 0.9894 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 31/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9902 - loss: 0.0506 - val_accuracy: 0.9895 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 32/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0509 - val_accuracy: 0.9895 - val_loss: 0.0506 - learning_rate: 0.0010
# Epoch 33/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0506 - val_accuracy: 0.9895 - val_loss: 0.0501 - learning_rate: 0.0010
# Epoch 34/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9898 - loss: 0.0535 - val_accuracy: 0.9895 - val_loss: 0.0508 - learning_rate: 0.0010
# Epoch 35/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0498 - val_accuracy: 0.9895 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 36/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9904 - loss: 0.0510 - val_accuracy: 0.9888 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 37/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9896 - loss: 0.0532 - val_accuracy: 0.9884 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 38/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0493 - val_accuracy: 0.9895 - val_loss: 0.0513 - learning_rate: 0.0010
# Epoch 39/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9899 - loss: 0.0508 - val_accuracy: 0.9895 - val_loss: 0.0515 - learning_rate: 0.0010
# Epoch 40/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0495 - val_accuracy: 0.9895 - val_loss: 0.0520 - learning_rate: 0.0010
# Epoch 41/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0506 - val_accuracy: 0.9895 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 42/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0525 - val_accuracy: 0.9895 - val_loss: 0.0507 - learning_rate: 0.0010
# Epoch 43/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9907 - loss: 0.0495 - val_accuracy: 0.9895 - val_loss: 0.0511 - learning_rate: 0.0010
# Epoch 44/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0507 - val_accuracy: 0.9890 - val_loss: 0.0518 - learning_rate: 0.0010
# Epoch 45/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0503 - val_accuracy: 0.9895 - val_loss: 0.0506 - learning_rate: 0.0010
# Epoch 46/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0472 - val_accuracy: 0.9888 - val_loss: 0.0508 - learning_rate: 0.0010
# Epoch 47/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0513 - val_accuracy: 0.9895 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 48/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0531 - val_accuracy: 0.9890 - val_loss: 0.0514 - learning_rate: 0.0010
# Epoch 49/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0524 - val_accuracy: 0.9895 - val_loss: 0.0518 - learning_rate: 0.0010
# Epoch 50/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0481 - val_accuracy: 0.9895 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 51/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0520 - val_accuracy: 0.9895 - val_loss: 0.0516 - learning_rate: 0.0010
# Epoch 52/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9901 - loss: 0.0510 - val_accuracy: 0.9895 - val_loss: 0.0507 - learning_rate: 0.0010
# Epoch 53/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9902 - loss: 0.0494 - val_accuracy: 0.9895 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 54/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9907 - loss: 0.0480 - val_accuracy: 0.9895 - val_loss: 0.0501 - learning_rate: 0.0010
# Epoch 55/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9903 - loss: 0.0500 - val_accuracy: 0.9895 - val_loss: 0.0516 - learning_rate: 0.0010
# Epoch 56/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9907 - loss: 0.0491 - val_accuracy: 0.9888 - val_loss: 0.0503 - learning_rate: 0.0010
# Epoch 57/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0507 - val_accuracy: 0.9895 - val_loss: 0.0507 - learning_rate: 0.0010
# Epoch 58/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9900 - loss: 0.0503 - val_accuracy: 0.9895 - val_loss: 0.0508 - learning_rate: 0.0010
# Epoch 59/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0503 - val_accuracy: 0.9890 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 60/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9904 - loss: 0.0502 - val_accuracy: 0.9895 - val_loss: 0.0510 - learning_rate: 0.0010
# Epoch 61/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9908 - loss: 0.0480 - val_accuracy: 0.9895 - val_loss: 0.0504 - learning_rate: 0.0010
# Epoch 62/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0481 - val_accuracy: 0.9895 - val_loss: 0.0513 - learning_rate: 0.0010
# Epoch 63/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0508 - val_accuracy: 0.9895 - val_loss: 0.0505 - learning_rate: 0.0010
# Epoch 64/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9904 - loss: 0.0501 - val_accuracy: 0.9895 - val_loss: 0.0504 - learning_rate: 0.0010
# Epoch 65/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9893 - loss: 0.0517 - val_accuracy: 0.9895 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 66/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9902 - loss: 0.0497 - val_accuracy: 0.9895 - val_loss: 0.0505 - learning_rate: 0.0010
# Epoch 67/100
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0506
# Epoch 67: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9901 - loss: 0.0506 - val_accuracy: 0.9895 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 68/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9907 - loss: 0.0484 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 5.0000e-04
# Epoch 69/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0527 - val_accuracy: 0.9895 - val_loss: 0.0504 - learning_rate: 5.0000e-04
# Epoch 70/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9902 - loss: 0.0505 - val_accuracy: 0.9895 - val_loss: 0.0505 - learning_rate: 5.0000e-04
# Epoch 71/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9904 - loss: 0.0493 - val_accuracy: 0.9895 - val_loss: 0.0505 - learning_rate: 5.0000e-04
# Epoch 72/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0490 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 5.0000e-04
# Epoch 73/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0502 - val_accuracy: 0.9895 - val_loss: 0.0505 - learning_rate: 5.0000e-04
# Epoch 74/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9901 - loss: 0.0517 - val_accuracy: 0.9895 - val_loss: 0.0501 - learning_rate: 5.0000e-04
# Epoch 75/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9907 - loss: 0.0490 - val_accuracy: 0.9895 - val_loss: 0.0506 - learning_rate: 5.0000e-04
# Epoch 76/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0496 - val_accuracy: 0.9895 - val_loss: 0.0506 - learning_rate: 5.0000e-04
# Epoch 77/100
# 111/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0507
# Epoch 77: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0506 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 5.0000e-04
# Epoch 78/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0518 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 2.5000e-04
# Epoch 79/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0475 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 2.5000e-04
# Epoch 80/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9902 - loss: 0.0501 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 2.5000e-04
# Epoch 81/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9909 - loss: 0.0473 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 2.5000e-04
# Epoch 82/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9900 - loss: 0.0502 - val_accuracy: 0.9895 - val_loss: 0.0506 - learning_rate: 2.5000e-04
# Epoch 83/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9906 - loss: 0.0473 - val_accuracy: 0.9895 - val_loss: 0.0501 - learning_rate: 2.5000e-04
# Epoch 84/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0502 - val_accuracy: 0.9895 - val_loss: 0.0506 - learning_rate: 2.5000e-04
# Epoch 85/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0493 - val_accuracy: 0.9895 - val_loss: 0.0505 - learning_rate: 2.5000e-04
# Epoch 86/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9893 - loss: 0.0529 - val_accuracy: 0.9895 - val_loss: 0.0508 - learning_rate: 2.5000e-04
# Epoch 87/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0496 - val_accuracy: 0.9895 - val_loss: 0.0504 - learning_rate: 2.5000e-04
# Epoch 88/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0494 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 2.5000e-04
# Epoch 89/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9898 - loss: 0.0509 - val_accuracy: 0.9895 - val_loss: 0.0501 - learning_rate: 2.5000e-04
# Epoch 90/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0485 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 2.5000e-04
# Epoch 91/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9911 - loss: 0.0467 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 2.5000e-04
# Epoch 92/100
# 112/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0475
# Epoch 92: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0476 - val_accuracy: 0.9895 - val_loss: 0.0505 - learning_rate: 2.5000e-04
# Epoch 93/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0488 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 1.2500e-04
# Epoch 94/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0483 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 1.2500e-04
# Epoch 95/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0496 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 1.2500e-04
# Epoch 96/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9905 - loss: 0.0477 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 1.2500e-04
# Epoch 97/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9901 - loss: 0.0493 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 1.2500e-04
# Epoch 98/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9905 - loss: 0.0484 - val_accuracy: 0.9895 - val_loss: 0.0501 - learning_rate: 1.2500e-04
# Epoch 99/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9899 - loss: 0.0511 - val_accuracy: 0.9895 - val_loss: 0.0502 - learning_rate: 1.2500e-04
# Epoch 100/100
# 115/115 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9895 - loss: 0.0516 - val_accuracy: 0.9895 - val_loss: 0.0503 - learning_rate: 1.2500e-04

# %%
# Load the best saved model
best_model = load_model('Saved_Models/IoMT_AI_IDS_DNN.keras')

# %%
pred = model.predict(X_train_test)
# Out:
# 457/457 ━━━━━━━━━━━━━━━━━━━━ 0s 537us/step

# %%
fig, ax = plt.subplots(figsize=(20, 16))

ax.plot(history.history['loss'], label='train')
ax.plot(history.history['val_loss'], label='test')
ax.set_title('Model Loss')
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
ax.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Results

# %% [markdown]
# ### Training

# %%
threshold = 0.5  # Adjust the threshold as needed
pred = (pred > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_train_test, pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
accuracy = accuracy_score(y_train_test, pred)
precision = precision_score(y_train_test, pred)
recall = recall_score(y_train_test, pred)
f1 = f1_score(y_train_test, pred)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   98.95%
# Precision:  99.91%
# Recall:     98.23%
# F1-score:   99.06%

# %% [markdown]
# ### with Test Dataset

# %%
pred_test = model.predict(X_test)
# Out:
# 254/254 ━━━━━━━━━━━━━━━━━━━━ 0s 451us/step

# %%
threshold = 0.5  # Adjust the threshold as needed
pred_test = (pred_test > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, pred_test)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Compute accuracy
accuracy = accuracy_score(y_test, pred_test)
precision = precision_score(y_test, pred_test)
recall = recall_score(y_test, pred_test)
f1 = f1_score(y_test, pred_test)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   99.11%
# Precision:  99.85%
# Recall:     98.59%
# F1-score:   99.21%
