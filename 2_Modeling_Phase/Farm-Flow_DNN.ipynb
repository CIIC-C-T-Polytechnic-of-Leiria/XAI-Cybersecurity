# %% [markdown]
# ## Import and Reading Data

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LeakyReLU
# Out:
# 2024-04-22 14:40:38.378403: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-22 14:40:38.378801: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-22 14:40:38.381075: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-22 14:40:38.409012: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-22 14:40:38.922476: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load Train and Test Datasets

# %%
# Load training data
df_train = pd.read_csv('../0_Datasets/Farm-Flow/train.csv')

# %%
# Load testing data
df_test = pd.read_csv('../0_Datasets/Farm-Flow/test.csv')

# %%
X_train = df_train.drop(['is_attack'], axis=1)  # Features
y_train = df_train['is_attack']  # Target variable

# %%
X_test = df_test.drop(['is_attack'], axis=1)  # Features
y_test = df_test['is_attack']  # Target variable

# %%
X_train, X_train_test, y_train, y_train_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# -----
# ## Create Model and Train Model

# %%
X_train.shape,y_train.shape
# Out:
# ((45453, 33), (45453,))

# %%
X_train_test.shape, y_train_test.shape
# Out:
# ((11364, 33), (11364,))

# %%
X_test.shape,y_test.shape
# Out:
# ((6312, 33), (6312,))

# %%
# %%time

# Define the model
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
# Out:
# CPU times: user 86.7 ms, sys: 10.4 ms, total: 97.1 ms
# Wall time: 96 ms
# /home/ivoafonsobispo/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-04-22 14:40:39.585155: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-22 14:40:39.585513: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Compile the model with learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Define early stopping
monitor = tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor=0.5,mode="min",patience=10,verbose=1,min_lr=1e-7)
checkpoint = ModelCheckpoint('Saved_Models/Farm-Flow_DNN.keras', monitor='val_loss', save_best_only=True)

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_train_test, y_train_test), epochs=100, batch_size=512, callbacks=[monitor, checkpoint])
# Out:
# Epoch 1/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.8006 - loss: 0.4868 - val_accuracy: 0.9312 - val_loss: 0.2699 - learning_rate: 0.0010
# Epoch 2/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9255 - loss: 0.2975 - val_accuracy: 0.9388 - val_loss: 0.2202 - learning_rate: 0.0010
# Epoch 3/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9346 - loss: 0.2510 - val_accuracy: 0.9403 - val_loss: 0.1986 - learning_rate: 0.0010
# Epoch 4/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9379 - loss: 0.2251 - val_accuracy: 0.9416 - val_loss: 0.1875 - learning_rate: 0.0010
# Epoch 5/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9385 - loss: 0.2046 - val_accuracy: 0.9417 - val_loss: 0.1776 - learning_rate: 0.0010
# Epoch 6/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9391 - loss: 0.1927 - val_accuracy: 0.9417 - val_loss: 0.1692 - learning_rate: 0.0010
# Epoch 7/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9398 - loss: 0.1846 - val_accuracy: 0.9417 - val_loss: 0.1661 - learning_rate: 0.0010
# Epoch 8/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9415 - loss: 0.1777 - val_accuracy: 0.9418 - val_loss: 0.1645 - learning_rate: 0.0010
# Epoch 9/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1761 - val_accuracy: 0.9420 - val_loss: 0.1633 - learning_rate: 0.0010
# Epoch 10/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9408 - loss: 0.1743 - val_accuracy: 0.9419 - val_loss: 0.1616 - learning_rate: 0.0010
# Epoch 11/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9390 - loss: 0.1762 - val_accuracy: 0.9420 - val_loss: 0.1614 - learning_rate: 0.0010
# Epoch 12/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1736 - val_accuracy: 0.9420 - val_loss: 0.1609 - learning_rate: 0.0010
# Epoch 13/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1728 - val_accuracy: 0.9420 - val_loss: 0.1604 - learning_rate: 0.0010
# Epoch 14/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.1682 - val_accuracy: 0.9419 - val_loss: 0.1603 - learning_rate: 0.0010
# Epoch 15/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9409 - loss: 0.1707 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 0.0010
# Epoch 16/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1710 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 17/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.1699 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 18/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9383 - loss: 0.1760 - val_accuracy: 0.9419 - val_loss: 0.1600 - learning_rate: 0.0010
# Epoch 19/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9409 - loss: 0.1717 - val_accuracy: 0.9420 - val_loss: 0.1599 - learning_rate: 0.0010
# Epoch 20/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9397 - loss: 0.1737 - val_accuracy: 0.9420 - val_loss: 0.1596 - learning_rate: 0.0010
# Epoch 21/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9415 - loss: 0.1710 - val_accuracy: 0.9420 - val_loss: 0.1597 - learning_rate: 0.0010
# Epoch 22/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9404 - loss: 0.1710 - val_accuracy: 0.9420 - val_loss: 0.1599 - learning_rate: 0.0010
# Epoch 23/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1696 - val_accuracy: 0.9419 - val_loss: 0.1603 - learning_rate: 0.0010
# Epoch 24/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1707 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 25/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9402 - loss: 0.1702 - val_accuracy: 0.9418 - val_loss: 0.1600 - learning_rate: 0.0010
# Epoch 26/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9417 - loss: 0.1679 - val_accuracy: 0.9418 - val_loss: 0.1600 - learning_rate: 0.0010
# Epoch 27/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9414 - loss: 0.1690 - val_accuracy: 0.9418 - val_loss: 0.1597 - learning_rate: 0.0010
# Epoch 28/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1700 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 29/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9423 - loss: 0.1665 - val_accuracy: 0.9418 - val_loss: 0.1600 - learning_rate: 0.0010
# Epoch 30/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9410 - loss: 0.1686 - val_accuracy: 0.9419 - val_loss: 0.1603 - learning_rate: 0.0010
# Epoch 31/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9420 - loss: 0.1660 - val_accuracy: 0.9419 - val_loss: 0.1603 - learning_rate: 0.0010
# Epoch 32/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9410 - loss: 0.1668 - val_accuracy: 0.9419 - val_loss: 0.1598 - learning_rate: 0.0010
# Epoch 33/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9405 - loss: 0.1695 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 0.0010
# Epoch 34/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1679 - val_accuracy: 0.9419 - val_loss: 0.1599 - learning_rate: 0.0010
# Epoch 35/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9410 - loss: 0.1697 - val_accuracy: 0.9419 - val_loss: 0.1598 - learning_rate: 0.0010
# Epoch 36/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9411 - loss: 0.1667 - val_accuracy: 0.9420 - val_loss: 0.1600 - learning_rate: 0.0010
# Epoch 37/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1664 - val_accuracy: 0.9417 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 38/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9420 - loss: 0.1658 - val_accuracy: 0.9418 - val_loss: 0.1599 - learning_rate: 0.0010
# Epoch 39/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.1676 - val_accuracy: 0.9418 - val_loss: 0.1601 - learning_rate: 0.0010
# Epoch 40/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.1663 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 0.0010
# Epoch 41/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.1666 - val_accuracy: 0.9417 - val_loss: 0.1601 - learning_rate: 0.0010
# Epoch 42/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9393 - loss: 0.1722 - val_accuracy: 0.9418 - val_loss: 0.1603 - learning_rate: 0.0010
# Epoch 43/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.1660 - val_accuracy: 0.9417 - val_loss: 0.1601 - learning_rate: 0.0010
# Epoch 44/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9440 - loss: 0.1619 - val_accuracy: 0.9418 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 45/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1677 - val_accuracy: 0.9417 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 46/100
# 78/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.1672
# Epoch 46: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9414 - loss: 0.1670 - val_accuracy: 0.9418 - val_loss: 0.1602 - learning_rate: 0.0010
# Epoch 47/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1670 - val_accuracy: 0.9417 - val_loss: 0.1605 - learning_rate: 5.0000e-04
# Epoch 48/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9423 - loss: 0.1646 - val_accuracy: 0.9418 - val_loss: 0.1599 - learning_rate: 5.0000e-04
# Epoch 49/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9428 - loss: 0.1633 - val_accuracy: 0.9418 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 50/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9399 - loss: 0.1680 - val_accuracy: 0.9419 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 51/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9429 - loss: 0.1628 - val_accuracy: 0.9419 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 52/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9435 - loss: 0.1632 - val_accuracy: 0.9419 - val_loss: 0.1603 - learning_rate: 5.0000e-04
# Epoch 53/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.1645 - val_accuracy: 0.9419 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 54/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9433 - loss: 0.1619 - val_accuracy: 0.9420 - val_loss: 0.1599 - learning_rate: 5.0000e-04
# Epoch 55/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.1652 - val_accuracy: 0.9421 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 56/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9427 - loss: 0.1624 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 57/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9405 - loss: 0.1652 - val_accuracy: 0.9417 - val_loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 58/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9436 - loss: 0.1628 - val_accuracy: 0.9418 - val_loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 59/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.1659 - val_accuracy: 0.9418 - val_loss: 0.1601 - learning_rate: 5.0000e-04
# Epoch 60/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9417 - loss: 0.1656 - val_accuracy: 0.9417 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 61/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.1645 - val_accuracy: 0.9419 - val_loss: 0.1599 - learning_rate: 5.0000e-04
# Epoch 62/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9422 - loss: 0.1654 - val_accuracy: 0.9418 - val_loss: 0.1599 - learning_rate: 5.0000e-04
# Epoch 63/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9431 - loss: 0.1626 - val_accuracy: 0.9417 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 64/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9420 - loss: 0.1628 - val_accuracy: 0.9417 - val_loss: 0.1601 - learning_rate: 5.0000e-04
# Epoch 65/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9414 - loss: 0.1649 - val_accuracy: 0.9417 - val_loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 66/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9435 - loss: 0.1597 - val_accuracy: 0.9418 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 67/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.1655 - val_accuracy: 0.9418 - val_loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 68/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1664 - val_accuracy: 0.9417 - val_loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 69/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9413 - loss: 0.1670 - val_accuracy: 0.9418 - val_loss: 0.1602 - learning_rate: 5.0000e-04
# Epoch 70/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9402 - loss: 0.1671 - val_accuracy: 0.9417 - val_loss: 0.1601 - learning_rate: 5.0000e-04
# Epoch 71/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9419 - loss: 0.1639 - val_accuracy: 0.9418 - val_loss: 0.1600 - learning_rate: 5.0000e-04
# Epoch 72/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9418 - loss: 0.1631 - val_accuracy: 0.9417 - val_loss: 0.1601 - learning_rate: 5.0000e-04
# Epoch 73/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9430 - loss: 0.1619 - val_accuracy: 0.9416 - val_loss: 0.1603 - learning_rate: 5.0000e-04
# Epoch 74/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.1652 - val_accuracy: 0.9417 - val_loss: 0.1604 - learning_rate: 5.0000e-04
# Epoch 75/100
# 84/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9411 - loss: 0.1643
# Epoch 75: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1643 - val_accuracy: 0.9417 - val_loss: 0.1601 - learning_rate: 5.0000e-04
# Epoch 76/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9434 - loss: 0.1625 - val_accuracy: 0.9416 - val_loss: 0.1604 - learning_rate: 2.5000e-04
# Epoch 77/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1653 - val_accuracy: 0.9416 - val_loss: 0.1606 - learning_rate: 2.5000e-04
# Epoch 78/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9422 - loss: 0.1633 - val_accuracy: 0.9417 - val_loss: 0.1603 - learning_rate: 2.5000e-04
# Epoch 79/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1651 - val_accuracy: 0.9417 - val_loss: 0.1603 - learning_rate: 2.5000e-04
# Epoch 80/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9420 - loss: 0.1640 - val_accuracy: 0.9418 - val_loss: 0.1600 - learning_rate: 2.5000e-04
# Epoch 81/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9409 - loss: 0.1664 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 2.5000e-04
# Epoch 82/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9411 - loss: 0.1659 - val_accuracy: 0.9417 - val_loss: 0.1602 - learning_rate: 2.5000e-04
# Epoch 83/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.1620 - val_accuracy: 0.9417 - val_loss: 0.1601 - learning_rate: 2.5000e-04
# Epoch 84/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9441 - loss: 0.1600 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 2.5000e-04
# Epoch 85/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9411 - loss: 0.1647 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 2.5000e-04
# Epoch 86/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1638
# Epoch 86: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9412 - loss: 0.1638 - val_accuracy: 0.9418 - val_loss: 0.1602 - learning_rate: 2.5000e-04
# Epoch 87/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9442 - loss: 0.1588 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 1.2500e-04
# Epoch 88/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9410 - loss: 0.1660 - val_accuracy: 0.9418 - val_loss: 0.1602 - learning_rate: 1.2500e-04
# Epoch 89/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9408 - loss: 0.1652 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 1.2500e-04
# Epoch 90/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9424 - loss: 0.1628 - val_accuracy: 0.9417 - val_loss: 0.1603 - learning_rate: 1.2500e-04
# Epoch 91/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9423 - loss: 0.1622 - val_accuracy: 0.9417 - val_loss: 0.1602 - learning_rate: 1.2500e-04
# Epoch 92/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9436 - loss: 0.1589 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 1.2500e-04
# Epoch 93/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9429 - loss: 0.1611 - val_accuracy: 0.9420 - val_loss: 0.1601 - learning_rate: 1.2500e-04
# Epoch 94/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9410 - loss: 0.1652 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 1.2500e-04
# Epoch 95/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9436 - loss: 0.1602 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 1.2500e-04
# Epoch 96/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9423 - loss: 0.1629 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 1.2500e-04
# Epoch 97/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9432 - loss: 0.1627 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 1.2500e-04
# Epoch 98/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9426 - loss: 0.1622 - val_accuracy: 0.9419 - val_loss: 0.1600 - learning_rate: 1.2500e-04
# Epoch 99/100
# 85/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9416 - loss: 0.1640
# Epoch 99: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9416 - loss: 0.1639 - val_accuracy: 0.9419 - val_loss: 0.1601 - learning_rate: 1.2500e-04
# Epoch 100/100
# 89/89 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9421 - loss: 0.1619 - val_accuracy: 0.9419 - val_loss: 0.1602 - learning_rate: 6.2500e-05

# %%
# Load the best saved model
best_model = load_model('Saved_Models/Farm-Flow_DNN.keras')

# %%
pred = model.predict(X_train_test)
# Out:
# 356/356 ━━━━━━━━━━━━━━━━━━━━ 0s 613us/step

# %%
fig, ax = plt.subplots(figsize=(20, 16))

ax.plot(history.history['loss'], label='train')
ax.plot(history.history['val_loss'], label='test')
ax.set_title('Model Loss')
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
ax.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Results

# %% [markdown]
# ### Training

# %%
threshold = 0.5  # Adjust the threshold as needed
pred = (pred > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_train_test, pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
accuracy = accuracy_score(y_train_test, pred)
precision = precision_score(y_train_test, pred)
recall = recall_score(y_train_test, pred)
f1 = f1_score(y_train_test, pred)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   94.19%
# Precision:  99.88%
# Recall:     91.73%
# F1-score:   95.63%

# %% [markdown]
# ### with Test Dataset

# %%
pred_test = model.predict(X_test)
# Out:
# 198/198 ━━━━━━━━━━━━━━━━━━━━ 0s 436us/step

# %%
threshold = 0.5  # Adjust the threshold as needed
pred_test = (pred_test > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, pred_test)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Compute accuracy
accuracy = accuracy_score(y_test, pred_test)
precision = precision_score(y_test, pred_test)
recall = recall_score(y_test, pred_test)
f1 = f1_score(y_test, pred_test)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   94.44%
# Precision:  99.80%
# Recall:     92.19%
# F1-score:   95.85%
