# %% [markdown]
# # DNN

# %% [markdown]
# ## Import and Reading Data

# %%
import pandas as pd
import joblib
import matplotlib.pyplot as plt
import numpy as np
import sklearn
import seaborn as sns
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score

from sklearn.model_selection import train_test_split

import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.models import Sequential, load_model
from tensorflow.keras.layers import Dense, Activation, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import LeakyReLU
# Out:
# 2024-04-18 14:37:09.148380: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-04-18 14:37:09.148875: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-18 14:37:09.151539: I external/local_tsl/tsl/cuda/cudart_stub.cc:32] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-04-18 14:37:09.184163: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-04-18 14:37:09.785136: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %% [markdown]
# ## Load Train and Test Datasets

# %%
# Load training data
df_train = pd.read_csv('../0_Datasets/CICIDS-2017/train.csv')

# %%
# Load testing data
df_test = pd.read_csv('../0_Datasets/CICIDS-2017/test.csv')

# %%
X_train = df_train.drop(['label'], axis=1)  # Features
y_train = df_train['label']  # Target variable

# %%
X_test = df_test.drop(['label'], axis=1)  # Features
y_test = df_test['label']  # Target variable

# %%
X_train, X_train_test, y_train, y_train_test = train_test_split(X_train, y_train, test_size=0.2, random_state=42)

# %% [markdown]
# -----
# ## Create Model and Train Model

# %%
X_train.shape,y_train.shape
# Out:
# ((205989, 7), (205989,))

# %%
X_train_test.shape, y_train_test.shape
# Out:
# ((51498, 7), (51498,))

# %%
X_test.shape,y_test.shape
# Out:
# ((28609, 7), (28609,))

# %%
# %%time

# Define the model
model = Sequential()
model.add(Dense(128, input_dim=X_train.shape[1], activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(128, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(32, activation='relu'))
model.add(BatchNormalization())
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))
# Out:
# CPU times: user 90.4 ms, sys: 12.8 ms, total: 103 ms
# Wall time: 100 ms
# /home/ivoafonsobispo/.local/lib/python3.10/site-packages/keras/src/layers/core/dense.py:86: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 2024-04-18 14:37:10.525431: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:998] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero. See more at https://github.com/torvalds/linux/blob/v6.0/Documentation/ABI/testing/sysfs-bus-pci#L344-L355
# 2024-04-18 14:37:10.525681: W tensorflow/core/common_runtime/gpu/gpu_device.cc:2251] Cannot dlopen some GPU libraries. Please make sure the missing libraries mentioned above are installed properly if you would like to use GPU. Follow the guide at https://www.tensorflow.org/install/gpu for how to download and setup the required libraries for your platform.
# Skipping registering GPU devices...

# %%
# Compile the model with learning rate
optimizer = Adam(learning_rate=0.001)
model.compile(loss='binary_crossentropy', optimizer=optimizer, metrics=['accuracy'])

# %%
# Define early stopping
monitor = tf.keras.callbacks.ReduceLROnPlateau(monitor="loss",factor=0.5,mode="min",patience=10,verbose=1,min_lr=1e-7)
checkpoint = ModelCheckpoint('Saved-Models/CICIDS-2017_DNN.keras', monitor='val_loss', save_best_only=True)

# %%
# Train the model
history = model.fit(X_train, y_train, validation_data=(X_train_test, y_train_test), epochs=100, batch_size=512, callbacks=[monitor, checkpoint])
# Out:
# Epoch 1/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - accuracy: 0.6973 - loss: 0.6250 - val_accuracy: 0.7863 - val_loss: 0.4225 - learning_rate: 0.0010
# Epoch 2/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.8981 - loss: 0.2964 - val_accuracy: 0.8351 - val_loss: 0.3582 - learning_rate: 0.0010
# Epoch 3/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9076 - loss: 0.2731 - val_accuracy: 0.7720 - val_loss: 0.5121 - learning_rate: 0.0010
# Epoch 4/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9106 - loss: 0.2633 - val_accuracy: 0.8959 - val_loss: 0.2994 - learning_rate: 0.0010
# Epoch 5/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9130 - loss: 0.2597 - val_accuracy: 0.8950 - val_loss: 0.2947 - learning_rate: 0.0010
# Epoch 6/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9185 - loss: 0.2461 - val_accuracy: 0.7290 - val_loss: 0.7681 - learning_rate: 0.0010
# Epoch 7/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9182 - loss: 0.2467 - val_accuracy: 0.8118 - val_loss: 0.4195 - learning_rate: 0.0010
# Epoch 8/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9199 - loss: 0.2423 - val_accuracy: 0.8118 - val_loss: 0.3982 - learning_rate: 0.0010
# Epoch 9/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9229 - loss: 0.2360 - val_accuracy: 0.7446 - val_loss: 0.6438 - learning_rate: 0.0010
# Epoch 10/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9206 - loss: 0.2408 - val_accuracy: 0.7484 - val_loss: 0.5685 - learning_rate: 0.0010
# Epoch 11/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9229 - loss: 0.2357 - val_accuracy: 0.8843 - val_loss: 0.2906 - learning_rate: 0.0010
# Epoch 12/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9214 - loss: 0.2376 - val_accuracy: 0.9045 - val_loss: 0.2457 - learning_rate: 0.0010
# Epoch 13/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9231 - loss: 0.2344 - val_accuracy: 0.4478 - val_loss: 0.8655 - learning_rate: 0.0010
# Epoch 14/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9215 - loss: 0.2357 - val_accuracy: 0.8998 - val_loss: 0.2480 - learning_rate: 0.0010
# Epoch 15/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9229 - loss: 0.2349 - val_accuracy: 0.9040 - val_loss: 0.3008 - learning_rate: 0.0010
# Epoch 16/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9243 - loss: 0.2310 - val_accuracy: 0.8791 - val_loss: 0.4131 - learning_rate: 0.0010
# Epoch 17/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9235 - loss: 0.2339 - val_accuracy: 0.9133 - val_loss: 0.2666 - learning_rate: 0.0010
# Epoch 18/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9243 - loss: 0.2306 - val_accuracy: 0.8812 - val_loss: 0.3004 - learning_rate: 0.0010
# Epoch 19/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9245 - loss: 0.2316 - val_accuracy: 0.8657 - val_loss: 0.3185 - learning_rate: 0.0010
# Epoch 20/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9244 - loss: 0.2294 - val_accuracy: 0.4544 - val_loss: 0.6277 - learning_rate: 0.0010
# Epoch 21/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.
# Epoch 57/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9258 - loss: 0.2240 - val_accuracy: 0.9118 - val_loss: 0.2573 - learning_rate: 5.0000e-04
# Epoch 58/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9272 - loss: 0.2221 - val_accuracy: 0.9175 - val_loss: 0.2292 - learning_rate: 5.0000e-04
# Epoch 59/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9272 - loss: 0.2205 - val_accuracy: 0.8648 - val_loss: 0.3318 - learning_rate: 5.0000e-04
# Epoch 60/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9273 - loss: 0.2207 - val_accuracy: 0.8626 - val_loss: 0.3503 - learning_rate: 5.0000e-04
# Epoch 61/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9266 - loss: 0.2220 - val_accuracy: 0.8911 - val_loss: 0.2988 - learning_rate: 5.0000e-04
# Epoch 62/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9270 - loss: 0.2216 - val_accuracy: 0.9168 - val_loss: 0.2498 - learning_rate: 5.0000e-04
# Epoch 63/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9273 - loss: 0.2206 - val_accuracy: 0.8590 - val_loss: 0.2997 - learning_rate: 5.0000e-04
# Epoch 64/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9268 - loss: 0.2218 - val_accuracy: 0.9169 - val_loss: 0.2298 - learning_rate: 5.0000e-04
# Epoch 65/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9266 - loss: 0.2226 - val_accuracy: 0.8610 - val_loss: 0.3214 - learning_rate: 5.0000e-04
# Epoch 66/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9273 - loss: 0.2211 - val_accuracy: 0.9128 - val_loss: 0.2491 - learning_rate: 5.0000e-04
# Epoch 67/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9287 - loss: 0.2180 - val_accuracy: 0.9214 - val_loss: 0.2307 - learning_rate: 5.0000e-04
# Epoch 68/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9279 - loss: 0.2193 - val_accuracy: 0.8866 - val_loss: 0.2942 - learning_rate: 5.0000e-04
# Epoch 69/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9263 - loss: 0.2223 - val_accuracy: 0.9150 - val_loss: 0.2445 - learning_rate: 5.0000e-04
# Epoch 70/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9275 - loss: 0.2201 - val_accuracy: 0.9163 - val_loss: 0.2326 - learning_rate: 5.0000e-04
# Epoch 71/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9271 - loss: 0.2197 - val_accuracy: 0.4441 - val_loss: 0.6075 - learning_rate: 5.0000e-04
# Epoch 72/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9271 - loss: 0.2211 - val_accuracy: 0.9076 - val_loss: 0.2732 - learning_rate: 5.0000e-04
# Epoch 73/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9277 - loss: 0.2199 - val_accuracy: 0.9230 - val_loss: 0.2316 - learning_rate: 5.0000e-04
# Epoch 74/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9276 - loss: 0.2207 - val_accuracy: 0.8820 - val_loss: 0.3133 - learning_rate: 5.0000e-04
# Epoch 75/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9260 - loss: 0.2224 - val_accuracy: 0.8913 - val_loss: 0.2683 - learning_rate: 5.0000e-04
# Epoch 76/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9280 - loss: 0.2195 - val_accuracy: 0.8409 - val_loss: 0.3324 - learning_rate: 5.0000e-04
# Epoch 77/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9276 - loss: 0.2219 - val_accuracy: 0.8452 - val_loss: 0.4098 - learning_rate: 5.0000e-04
# Epoch 78/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9279 - loss: 0.2184 - val_accuracy: 0.8813 - val_loss: 0.3414 - learning_rate: 5.0000e-04
# Epoch 79/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9265 - loss: 0.2235 - val_accuracy: 0.9118 - val_loss: 0.2518 - learning_rate: 5.0000e-04
# Epoch 80/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9272 - loss: 0.2206 - val_accuracy: 0.9146 - val_loss: 0.2423 - learning_rate: 5.0000e-04
# Epoch 81/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9270 - loss: 0.2210 - val_accuracy: 0.8605 - val_loss: 0.3558 - learning_rate: 5.0000e-04
# Epoch 82/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9281 - loss: 0.2185 - val_accuracy: 0.8848 - val_loss: 0.3261 - learning_rate: 5.0000e-04
# Epoch 83/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9274 - loss: 0.2193 - val_accuracy: 0.8609 - val_loss: 0.3659 - learning_rate: 5.0000e-04
# Epoch 84/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9261 - loss: 0.2237 - val_accuracy: 0.9287 - val_loss: 0.2549 - learning_rate: 5.0000e-04
# Epoch 85/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9275 - loss: 0.2208 - val_accuracy: 0.7970 - val_loss: 0.5144 - learning_rate: 5.0000e-04
# Epoch 86/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9261 - loss: 0.2215 - val_accuracy: 0.9216 - val_loss: 0.2375 - learning_rate: 5.0000e-04
# Epoch 87/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9278 - loss: 0.2189 - val_accuracy: 0.7958 - val_loss: 0.5497 - learning_rate: 5.0000e-04
# Epoch 88/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9278 - loss: 0.2196 - val_accuracy: 0.8503 - val_loss: 0.3679 - learning_rate: 5.0000e-04
# Epoch 89/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9272 - loss: 0.2207 - val_accuracy: 0.8758 - val_loss: 0.3029 - learning_rate: 5.0000e-04
# Epoch 90/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9284 - loss: 0.2174 - val_accuracy: 0.8886 - val_loss: 0.2785 - learning_rate: 5.0000e-04
# Epoch 91/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9263 - loss: 0.2215 - val_accuracy: 0.8907 - val_loss: 0.3200 - learning_rate: 5.0000e-04
# Epoch 92/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9266 - loss: 0.2213 - val_accuracy: 0.9166 - val_loss: 0.2387 - learning_rate: 5.0000e-04
# Epoch 93/100
# 395/403 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9272 - loss: 0.2211
# Epoch 93: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9272 - loss: 0.2211 - val_accuracy: 0.8966 - val_loss: 0.2561 - learning_rate: 5.0000e-04
# Epoch 94/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9278 - loss: 0.2191 - val_accuracy: 0.8533 - val_loss: 0.3770 - learning_rate: 2.5000e-04
# Epoch 95/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9277 - loss: 0.2193 - val_accuracy: 0.8923 - val_loss: 0.3035 - learning_rate: 2.5000e-04
# Epoch 96/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9275 - loss: 0.2192 - val_accuracy: 0.8884 - val_loss: 0.3152 - learning_rate: 2.5000e-04
# Epoch 97/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9276 - loss: 0.2201 - val_accuracy: 0.8187 - val_loss: 0.5159 - learning_rate: 2.5000e-04
# Epoch 98/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9269 - loss: 0.2210 - val_accuracy: 0.9185 - val_loss: 0.2434 - learning_rate: 2.5000e-04
# Epoch 99/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9284 - loss: 0.2186 - val_accuracy: 0.8563 - val_loss: 0.3869 - learning_rate: 2.5000e-04
# Epoch 100/100
# 403/403 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9274 - loss: 0.2181 - val_accuracy: 0.8929 - val_loss: 0.2690 - learning_rate: 2.5000e-04

# %%
# Load the best saved model
best_model = load_model('Saved-Models/CICIDS-2017_DNN.keras')

# %%
pred = model.predict(X_train_test)
# Out:
# 1610/1610 ━━━━━━━━━━━━━━━━━━━━ 1s 487us/step

# %%
fig, ax = plt.subplots(figsize=(20, 16))

ax.plot(history.history['loss'], label='train')
ax.plot(history.history['val_loss'], label='test')
ax.set_title('Model Loss')
ax.set_ylabel('Loss')
ax.set_xlabel('Epoch')
ax.legend(['Train', 'Test'], loc='upper right')
plt.show()

# %% [markdown]
# ## Results

# %% [markdown]
# ### Training

# %%
threshold = 0.5  # Adjust the threshold as needed
pred = (pred > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_train_test, pred)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
accuracy = accuracy_score(y_train_test, pred)
precision = precision_score(y_train_test, pred)
recall = recall_score(y_train_test, pred)
f1 = f1_score(y_train_test, pred)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   89.29%
# Precision:  84.79%
# Recall:     98.38%
# F1-score:   91.08%

# %% [markdown]
# ### with Test Dataset

# %%
pred_test = model.predict(X_test)
# Out:
# 895/895 ━━━━━━━━━━━━━━━━━━━━ 0s 442us/step

# %%
threshold = 0.5  # Adjust the threshold as needed
pred_test = (pred_test > threshold).astype(int)

# %%
# Compute confusion matrix
cm = confusion_matrix(y_test, pred_test)

plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
            xticklabels=['Normal', 'Malicious'], 
            yticklabels=['Normal', 'Malicious'])
plt.xlabel('Predicted')
plt.ylabel('True')
plt.title('Confusion Matrix')
plt.show()

# %%
# Compute accuracy
accuracy = accuracy_score(y_test, pred_test)
precision = precision_score(y_test, pred_test)
recall = recall_score(y_test, pred_test)
f1 = f1_score(y_test, pred_test)

print("Accuracy:   {:.2%}".format(accuracy))
print("Precision:  {:.2%}".format(precision))
print("Recall:     {:.2%}".format(recall))
print("F1-score:   {:.2%}".format(f1))
# Out:
# Accuracy:   88.14%
# Precision:  83.67%
# Recall:     97.70%
# F1-score:   90.14%
